# %% [markdown]
# # Vector projection exercises

# %%
from fractions import Fraction

from vector_diagram import plot_vector

# %% [markdown]
# ## Exercise 1
#
# The following diagram shows a vector with length $r_1 = 5$ and an angle to the positive $x$-axis of $\pi/3$.
#
#   - What is the general equation for the projection of the vector onto the $x$-axis (the red arrow in the diagram)?
#   - What is the general equation for the projection of the vector onto the $y$-axis (the green arrow in the diagram)?
#   - What is the value of the length of the projection onto the $x$-axis?
#   - What is the value of the length of the projection onto the $y$-axis?

# %%
plot_vector(r=5, theta=Fraction('1/3'), subscript=1, plot_projections=True)

# %% [markdown]
# ## Exercise 2
#
# The following diagram shows a vector with length $r_2 = 0.5$ and an angle to the positive $x$-axis of $-2\pi/3$.
#
#   - Draw the projections of the vector onto the $x$- and $y$-axes respectively.
#   - What are the lengths of the projections?

# %%
plot_vector(r=0.5, theta=Fraction('-2/3'), subscript=2)

# %% [markdown]
# ## Exercise 3
#
# The following diagram shows a vector with length $r_2 = 2$ and an angle to the positive $x$-axis of $-\pi/6$.
#
#   - Draw the projections of the vector onto the $x$- and $y$-axes respectively.
#   - What are the lengths of the projections?

# %%
plot_vector(r=2, theta=Fraction('-1/6'), subscript=3)

# %% [markdown]
# ## Exercise 4
#
# The following diagram shows a vector with length $r_2 = 4.5$ and an angle to the positive $x$-axis of $3\pi/4$.
#
#   - Draw the projections of the vector onto the $x$- and $y$-axes respectively.
#   - What are the lengths of the projections?
#   - What is the equation for the length of the projection of the vector onto the $x$-axis?
#   - What is the equation for the length of the projection of the vector onto the $y$-axis?

# %%
plot_vector(r=4.5, theta=Fraction('3/4'), subscript=4)
